# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
# %matplotlib inline
pd.set_option('display.max_columns', 100)

# %%
allPair = pd.read_csv("../data/allPair.csv",low_memory=False)
CA = allPair[allPair["state"] == "CA"]
CAgroup = CA.groupby('UniversityName')
CAgroupCount = CAgroup.size()
# print CAgroupCount
# print CAgroupCount.to_dict().items()

# %%
print len(CAgroupCount)
# Out:
# 151

# %%
CAgroupCount.sort_values(inplace=True,ascending=False)
distCorrDF = pd.DataFrame({"UniversityName":CAgroupCount.index, "homeCount":CAgroupCount.values})
print distCorrDF
# Out:
#                                         UniversityName  homeCount
# 0                               University of Redlands       1269
# 1                            William Jessup University        983
# 2       California State University   - San Bernardino        783
# 3          California State University   - Bakersfield        527
# 4                                    The Sage Colleges        422
# 5                      Westminster Seminary California        394
# 6                                   Simpson University        372
# 7           California State University   - Sacramento        362
# 8                            Fresno Pacific University        316
# 9           California State University   - Stanislaus        297
# 10                           University of the Pacific        295
# 11               California State University   - Chico        288
# 12                                The Master's College        283
# ...

# %%
universities = pd.read_csv("../data/university.csv")
CAuniv = universities.groupby("state").get_group("CA")

# %%
print CAuniv.shape
print CAuniv.head()
# Out:
# (162, 17)
#                           UniversityName              streetaddr  \
# 3              Academy of Art University    79 New Montgomery St
# 32      Alliant International University      1000 S Fremont Ave
# 40         American Conservatory Theater            30 Grant Ave
# 41               American Film Institute      2021 N Western Ave
# 43  American InterContinental University  12655 W Jefferson Blvd
#
#              city state postcode acceptanceRate ranking enroll   latitude  \
# 3   San Francisco    CA    94105             \N      \N     \N  37.787830
# 32       Alhambra    CA    91803             \N      \N     \N  34.081716
# 40  San Francisco    CA    94108             \N      \N     29  37.787368
# 41    Los Angeles    CA    90027             \N      \N     \N  34.107612
# 43    Los Angeles    CA    90066             \N      \N     \N  33.979372
#
#      longitude                         type endowment acadStaff students  \
# ...

# %%
univNames = distCorrDF['UniversityName'].tolist()
print len(univNames)
distCorrDF['distCorr'] = np.nan
# print distCorrDF.head()
# i = 0
# univ = distCorrDF.loc[distCorrDF.index[i], 'university']
# print univ
# df = CAgroup.get_group(univ)
# corr = df.corr()
# dc = corr['saleprice']['distance']
# distCorrDF.loc[distCorrDF.index[i], 'distCorr'] = dc
# print distCorrDF.head()

for i in range(len(univNames)):
    univ = distCorrDF.loc[distCorrDF.index[i], 'UniversityName']
    df = CAgroup.get_group(univ)
    corr = df.corr()
    distCorrDF.loc[distCorrDF.index[i], 'distCorr'] = corr['saleprice']['distance']

print distCorrDF.head()
# Out:
# 151
#                                    UniversityName  homeCount  distCorr
# 0                          University of Redlands       1269 -0.010105
# 1                       William Jessup University        983  0.156045
# 2  California State University   - San Bernardino        783  0.043071
# 3     California State University   - Bakersfield        527 -0.118332
# 4                               The Sage Colleges        422  0.164001

# %%
univDistCorrDF = pd.merge(CAuniv, distCorrDF, on='UniversityName', how='inner')
print univDistCorrDF.info()
print "******* convert data type to numeric ********"
toConvert = ["acceptanceRate","ranking","enroll","acadStaff","students","underGrad","postGrad"]
for col in toConvert:
    univDistCorrDF[col] = pd.to_numeric(univDistCorrDF[col], errors='coerce')

print univDistCorrDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 0 to 150
# Data columns (total 19 columns):
# UniversityName    151 non-null object
# streetaddr        151 non-null object
# city              151 non-null object
# state             151 non-null object
# postcode          151 non-null object
# acceptanceRate    151 non-null object
# ranking           151 non-null object
# enroll            151 non-null object
# latitude          151 non-null float64
# longitude         151 non-null float64
# type              151 non-null object
# endowment         151 non-null object
# acadStaff         151 non-null object
# students          151 non-null object
# underGrad         151 non-null object
# postGrad          151 non-null object
# website           151 non-null object
# homeCount         151 non-null int64
# distCorr          150 non-null float64
# dtypes: float64(3), int64(1), object(15)
# memory usage: 23.6+ KB
# None
# ******* convert data type to numeric ********
# ...

# %% [markdown]
# Plot distCorr vs different things

# %%
for x in toConvert:
    plt.figure()
    univDistCorrDF = univDistCorrDF.sort(columns=x)
    plt.plot(univDistCorrDF[x], univDistCorrDF['distCorr'])
    plt.xlabel(x)
    plt.ylabel("distCorr")
    plt.show()
# Out:
# /home/wuyi/.local/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
