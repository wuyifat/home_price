# %%
import numpy as np
import pandas as pd

# %%
#home = pd.read_csv("home.csv")
university = pd.read_csv("university.csv")

# %%
pwd
# Out:
# u'/home/wuyi/Code/Hristidis'

# %%
university.head()
# Out:
#                              UniversityName            streetaddr  \
# 0  A.T. Still University of Health Sciences    800 W Jefferson St
# 1              Abilene Christian University        1600 Campus Ct
# 2      Abraham Baldwin Agricultural College        2802 Moore Hwy
# 3                 Academy of Art University  79 New Montgomery St
# 4                       Adams State College     208 Edgemont Blvd
#
#             city state postcode acceptanceRate ranking enroll   latitude  \
# 0     Kirksville    MO    63501             \N      \N   3624  40.193391
# 1        Abilene    TX    79601             64      \N   4558  32.471081
# 2         Tifton    GA    31793             69      \N   3284  31.489239
# 3  San Francisco    CA    94105             \N      \N     \N  37.787830
# 4        Alamosa    CO    81102             64      \N   3701  37.469954
#
#     longitude                    type endowment acadStaff students underGrad  \
# ...

# %%
home = pd.read_csv("home.csv")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-12-f25bdc0ffdfa> in <module>()
# ----> 1 home = pd.read_csv("home.csv")
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
with open('homeErr.txt') as f:
    for line in f:
        num = len(line.split(','))
        print num
# Out:
# 58
# 42

# %%
he = pd.read_csv('homee1.csv')

# %%
he.head()
# Out:
#                                                                                                                                             website  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417 -121.69016
#                       http://www.trulia.com/builder-community/Brighto... single_family_home sale trulia_sale_builder_community 33.819195 -118.29354
#
#                                                                                                                                                                         home_url  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417  813 Shearwater Way Contra Costa County
#                       http://www.trulia.com/builder-community/Brighto... single_family_home sale trulia_sale_builder_community 33.819195          West Carson Los Angeles County
#
# ...

# %%
he.size
he.shape
# Out:
# (2, 39)

# %%
h0 = he.iloc[0]
h1 = he.iloc[1]

# %%
print len(h0)
# Out:
# 39

# %%
print len(h1)
# Out:
# 39

# %%
h0
# Out:
# website                                                          -121.69
# home_url                          813 Shearwater Way Contra Costa County
# property_type                                                     Oakley
# record_type                                                           CA
# parser_type                                                        94561
# latitude                                                             USA
# longitude                                                             -1
# streetaddr                                                            -1
# city                                                                  -1
# state                                                                 -1
# zipcode                                                               -1
# country                                                                0
# numbed                                                                \N
# ...

# %%
h1
# Out:
# website                                                         -118.294
# home_url                                  West Carson Los Angeles County
# property_type                                                Los Angeles
# record_type                                                           CA
# parser_type                                                        90502
# latitude                                                             USA
# longitude                                                             -1
# streetaddr                                                            -1
# city                                                                  -1
# state                                                                 -1
# zipcode                                                               -1
# country                                                                0
# numbed                                                                \N
# ...

# %%
line40 = pd.read_csv('line40.csv')

# %%
line40.head()
# Out:
#                  website                                           home_url  \
# 0  http://www.trulia.com  http://www.trulia.com/builder-community/Bright...
#
#         property_type record_type                    parser_type   latitude  \
# 0  single_family_home        sale  trulia_sale_builder_community  33.819195
#
#    longitude                      streetaddr         city state    ...     \
# 0 -118.29354  West Carson Los Angeles County  Los Angeles    CA    ...
#
#    fireplace floorType  kitchenCountertop  renovation  elevation  \
# 0          0     tiles                 \N           0   13.85935
#
#    elevationType                                        description  \
# 0           flat  new community in torrance, ca offering 3 home ...
#
#             crawl_time datalisted  inactive
# 0  2016-07-01 07:34:12         \N        \N
#
# [1 rows x 39 columns]

# %%
line25 = pd.read_csv('line25.csv')

# %%
line25.head()
# Out:
#                                                                                                                                             website  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417 -121.69016
#
#                                                                                                                                                                         home_url  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417  813 Shearwater Way Contra Costa County
#
#                                                                                                                                          property_type  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417        Oakley
#
# ...

# %%
line25
# Out:
#                                                                                                                                             website  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417 -121.69016
#
#                                                                                                                                                                         home_url  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417  813 Shearwater Way Contra Costa County
#
#                                                                                                                                          property_type  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417        Oakley
#
# ...

# %%
l25 = pd.read_csv('line25_sqll.csv')

# %%
l25
# Out:
#                                                                                                                                             website  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417 -121.69016
#
#                                                                                                                                                                         home_url  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417  813 Shearwater Way Contra Costa County
#
#                                                                                                                                          property_type  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417        Oakley
#
# ...

# %%
m25 = pd.read_csv('makeup25.csv')
m25
# Out:
#                                a            b           c
# flat  oakley, \ delta \" today a   landscape"  2016-07-01

# %%
with open("homee1.csv") as f:
    #header = next(f)
    for line in f:
        print line.count("\"")
# Out:
# 0
# 64
# 62

# %%
homee1 = pd.read_csv("homee1.csv")
homee1.shape
# Out:
# (2, 39)

# %%
homee1
# Out:
#                                                                                                                                             website  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417 -121.69016
#                       http://www.trulia.com/builder-community/Brighto... single_family_home sale trulia_sale_builder_community 33.819195 -118.29354
#
#                                                                                                                                                                         home_url  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417  813 Shearwater Way Contra Costa County
#                       http://www.trulia.com/builder-community/Brighto... single_family_home sale trulia_sale_builder_community 33.819195          West Carson Los Angeles County
#
# ...

# %%
l25.shape
# Out:
# (1, 39)

# %%
l25
# Out:
#                                                                                                                                             website  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417 -121.69016
#
#                                                                                                                                                                         home_url  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417  813 Shearwater Way Contra Costa County
#
#                                                                                                                                          property_type  \
# http://www.trulia.com http://www.trulia.com/builder-community/Aspen-a... single_family_home sale trulia_sale_builder_community 38.004417        Oakley
#
# ...

# %%
home.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-101-487fb4b4b134> in <module>()
# ----> 1 home.shape
#
# NameError: name 'home' is not defined

# %%
home30day_top5 = pd.read_csv("home30day.csv",low_memory=False,nrows=5)
home30day_top5.shape
# Out:
# (5, 39)

# %%
home30day_top5
# Out:
#                  website  home_url property_type record_type parser_type  \
# 0  http://www.trulia.com       NaN          null        sale        null
# 1  http://www.trulia.com       NaN          null        sale        null
# 2  http://www.trulia.com       NaN          null        sale        null
# 3  http://www.trulia.com       NaN          null        rent        null
# 4  http://www.trulia.com       NaN          null        sale        null
#
#     latitude   longitude                             streetaddr  \
# 0  41.812466 -124.157240  3725 Wonder Stump Rd Del Norte County
# 1  34.825233  -86.510290     108 Tammy Gaines Ln Madison County
# 2  33.976627 -118.353325    386 Hillsdale St Los Angeles County
# 3  35.704716  -85.359730    425 High Meadow Dr Van Buren County
# 4  31.230778  -85.907150     2814 County Road 651 Geneva County
#
#             city state    ...     fireplace floorType  kitchenCountertop  \
# ...

# %%
university.shape
# Out:
# (1991, 17)

# %%
home30day_top5['state'].isin(['CA'])
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# Name: state, dtype: bool
